# %%
import tweepy
import pandas as pd
import os
import datetime
import json
import boto3
import io
import time

# %%
def upload_raw_data(key,data,s3_client,keyword,date):
    buf = io.StringIO()

    # write each dictionary to a separate line in the buffer
    for item in data:
        if key == 'tweets':
            item['keyword'] = keyword
        json.dump(item, buf)
        buf.write('\n')
    
    date = str(date.date())
    
    response = s3_client.put_object(
        Bucket='santal', 
        Key=f'{key}/{keyword}/{date}.json',
        Body=buf.getvalue()
        )
    
    return response

# %%
def search_and_upload(keyword,tweepy_client,s3_client,max_page = 100):
    
    tweet_fields = ['created_at','public_metrics','possibly_sensitive','text','id','geo']
    expansions = ['author_id','geo.place_id']
    place_fields = ['id','country','full_name','contained_within','place_type','geo']
    user_fields = ['description','id','location','name','verified','verified_type']
    
    
    date = datetime.datetime.today() - datetime.timedelta(days = 1)
    query = f"{keyword} -is:retweet -is:reply lang:EN"
    
    pages = 0
    tweets = []
    users = []
    places = []
    
    #100 page * 100 result
    next_token = None
    
    while pages < max_page:
        response = tweepy_client.search_recent_tweets(query=query,start_time = date,
                                 next_token = next_token,
                                 tweet_fields = tweet_fields,
                                 place_fields = place_fields,
                                 user_fields = user_fields,
                                 expansions=expansions,
                                 max_results=100)
        
        tweets+=response['data']
        users+=response['includes']['users']
        try:
            places+=response['includes']['places']
        except:
            pass
        
        pages+=1
        try:
            next_token = response['meta']['next_token']
            print(pages)
        except:
            print(pages*100 + response['meta']['result_count'])
            break
        
        time.sleep(3)
    return response
#     upload_raw_data('tweets',tweets,s3_client,keyword,date)
#     upload_raw_data('users',users,s3_client,keyword,date)
#     upload_raw_data('places',places,s3_client,keyword,date)

# %%
#build tweepy client
bearer_token = os.environ['TWEEPY_BEARER_TOKEN']
tweepy_client = tweepy.Client(bearer_token=bearer_token,return_type=dict,wait_on_rate_limit=True)

#build s3 client
aws_key = os.environ['AWS_ACCESS_KEY']
aws_secret = os.environ['AWS_ACCESS_SECRET']
s3_client = boto3.client('s3',aws_access_key_id=aws_key,aws_secret_access_key=aws_secret)
search_and_upload('test',tweepy_client,s3_client,max_page=1)
# Out:
# 1
# {'data': [{'text': 'Bernie Sanders: Nikki Haley’s demand for mental tests is ageist and ‘absurd’ Bernie is afraid he can’t pass the test along with many other liberal dems with mental disorders!',
#    'author_id': '1306583233279164416',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490375492603904',
#    'edit_history_tweet_ids': ['1627490375492603904'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:37.000Z'},
#   {'text': '✰ math commissions,algebra genmath,integral calculus ,geometry ,trigonometry ,statistics , proving , solving , timed exam , assignment , seatwork , activities , test , quizzes, science , physics,chemistry , biology, earth science, rush lf client',
#    'author_id': '1494191459641475074',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490366126714880',
#    'edit_history_tweet_ids': ['1627490366126714880'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:35.000Z'},
#   {'text': '[XG TAPE #2] Surround Sound (TEST VIDEO / COCONA) https://t.co/sqlxLKJspD via @YouTube WHAAAT',
#    'author_id': '1454115109983309824',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490365518524417',
#    'edit_history_tweet_ids': ['1627490365518524417'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:35.000Z'},
#   {'text': 'Question for the medical professionals - given that you can be infected and positive on a test for SARS-CoV-2 but asymptomatic, does that infection, strictly speaking, count as COVID-19 (given it has not caused disease symptoms)? That is, is infection always counted as disease?',
#    'author_id': '596203049',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490335520874503',
#    'edit_history_tweet_ids': ['1627490335520874503'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:27.000Z'},
#   {'text': 'Your works ever there was a test, too. Is Shimmer a\n؟?\n\u2066سےفے\u2066\n\n🔹X9🔹\n🔹X9🔹\n🔹X9🔹',
#    'author_id': '417267257',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490330416230402',
#    'edit_history_tweet_ids': ['1627490330416230402'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:26.000Z'},
#   {'text': 'The more he say drug test the funnier it gets 😂 https://t.co/XqsXYcMRRX',
#    'author_id': '392389232',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490323084484608',
#    'edit_history_tweet_ids': ['1627490323084484608'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:24.000Z'},
#   {'text': '💯😌💫💘👋\nTest team perform remember bill opportunity policy.\nyun lover kk220  #淫水 #调教 #吃瓜   https://t.co/WDyalI5iMw',
#    'author_id': '4498583483',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490318714273793',
#    'edit_history_tweet_ids': ['1627490318714273793'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:23.000Z'},
#   {'text': '👌👋💥😋💌\nTest price west business.\nyun lover kk220  #射屏 #肛交  #做爱  https://t.co/VCrBQ3EhaM',
#    'author_id': '3308947671',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490316927516673',
#    'edit_history_tweet_ids': ['1627490316927516673'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:23.000Z'},
#   {'text': '#BREAKING: Australia captain Pat Cummins will rush home from India mid Test series to deal with a private family matter. #TheAdvertiser @TheTiserSport https://t.co/nOy8HSajKK https://t.co/hxUX1HIFNh',
#    'author_id': '9609582',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 7},
#    'id': '1627490300783472640',
#    'edit_history_tweet_ids': ['1627490300783472640'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:19.000Z'},
#   {'text': 'So now we have to pay $11.99 a month for security and customer service we should have had to begin with? 😩😡 \n\nhttps://t.co/gXuggFh0zs \n\n#MetaVerified',
#    'author_id': '14597992',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490300695568384',
#    'edit_history_tweet_ids': ['1627490300695568384'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:19.000Z'},
#   {'text': 'test',
#    'author_id': '1627489899766255618',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490289094123520',
#    'edit_history_tweet_ids': ['1627490289094123520'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:16.000Z'},
#   {'text': 'Dude was close as shit to getting 50/50 vote, he\'s breaking the 4th wall before his last moments to tell us to vote Muu innocent, and now he\'s most likely gonna be the example of "What happens when a prisoner gets death choosen early for them?"\n\nIS HE A FUCKING TEST SUBJECT??? https://t.co/Lj2ScWNaI5',
#    'author_id': '1551012893931495424',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490273537269762',
#    'edit_history_tweet_ids': ['1627490273537269762'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:13.000Z'},
#   {'text': '#推特账号  #广告代发 #推特号 #推特引流 https://t.co/RMj3kqWyi8\nYoung tax relationship test or.\n😅💋💘💥😀',
#    'author_id': '3392135501',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490265668943872',
#    'edit_history_tweet_ids': ['1627490265668943872'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:11.000Z'},
#   {'text': '🤐😄💌😋😆\nTest finish she.\nalbaisn220  #裸聊  #性奴  https://t.co/hkDV9frdk0',
#    'author_id': '2992951109',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490256324026368',
#    'edit_history_tweet_ids': ['1627490256324026368'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:09.000Z'},
#   {'text': '#制服 #滴蜡 #叫床  https://t.co/tA1inKO7AV\nAdministration toward rock bed test drive.\n💋💯😄😍💘',
#    'author_id': '3023150972',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490248925257728',
#    'edit_history_tweet_ids': ['1627490248925257728'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:07.000Z'},
#   {'text': "I'm Real like HIV, MF wonna test Me 💉",
#    'author_id': '1580813015942823936',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490245691293696',
#    'edit_history_tweet_ids': ['1627490245691293696'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:06.000Z'},
#   {'text': "It Is Not Easy Anymore To Figure Out What Is Love? Whose Is Love? While It Is Neither The Best Thing To Test On Someone's Love. Your Doubt Can Even Let Loose The One Who Love You.",
#    'author_id': '374947039',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490229027475457',
#    'edit_history_tweet_ids': ['1627490229027475457'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:08:02.000Z'},
#   {'text': '"Few of us ever test our powers of deduction, except when filling out an income tax form." #mosyantax',
#    'author_id': '1854013405',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490208525733889',
#    'edit_history_tweet_ids': ['1627490208525733889'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:57.000Z'},
#   {'text': 'KL Rahul retains his place in test squad for remaining two tests against Australia, no more vice-captain |\xa0XtraTime https://t.co/urIywpRVod',
#    'author_id': '1617121124399349761',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490207884021761',
#    'edit_history_tweet_ids': ['1627490207884021761'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:57.000Z'},
#   {'text': 'new diet idea\n\nAP test diet\nrules: cannot eat until AP unit tests are passed (unless family forced) Spend all time studying for AP test in may',
#    'author_id': '1575701257578483712',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490199407034369',
#    'edit_history_tweet_ids': ['1627490199407034369'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:55.000Z'},
#   {'text': 'Frog Pool &amp; Hot Tub Test Strips - 100 Count (pack of 2 - 50 strips) P0UTM8W\n\nhttps://t.co/O6PEAlI0mQ',
#    'author_id': '1584891545970417664',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490194948595713',
#    'edit_history_tweet_ids': ['1627490194948595713'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:54.000Z'},
#   {'text': 'Test',
#    'author_id': '1517757714520481792',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490193023574017',
#    'edit_history_tweet_ids': ['1627490193023574017'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:53.000Z'},
#   {'text': 'Requesting faucet funds into 0x42cB88358f2188B9Af49c0D9cbFb99c27110E4b3 on the #Goerli #Ethereum test network via https://t.co/sNtuxTUQIP',
#    'author_id': '923300302253580288',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627490188535693313',
#    'edit_history_tweet_ids': ['1627490188535693313'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:52.000Z'},
#   {'text': 'test',
#    'author_id': '1961873594',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490185327050753',
#    'edit_history_tweet_ids': ['1627490185327050753'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:52.000Z'},
#   {'text': 'Courier Mail altered a news headline: https://t.co/oERjVhegP0 https://t.co/3c1bjCFnov',
#    'author_id': '1435019380186701826',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 4},
#    'id': '1627490170109845506',
#    'edit_history_tweet_ids': ['1627490170109845506'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:48.000Z'},
#   {'text': 'New Warnings have been issued for Georgia.  #test https://t.co/XBjxjCroOW',
#    'author_id': '2387680477',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490160425279488',
#    'edit_history_tweet_ids': ['1627490160425279488'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:46.000Z'},
#   {'text': 'To #BuildonMantle, I am claiming test $BIT tokens on https://t.co/CUqUVqnTXl for @0xMantle, a next generation high-performance modular @Ethereum L2 built for hyperscaled dApps.\n\nLearn more: [https://t.co/W2mfMK4jQZ]',
#    'author_id': '1338501184273846273',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490157204238336',
#    'edit_history_tweet_ids': ['1627490157204238336'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:45.000Z'},
#   {'text': 'What do you mean, @BigScreenLeaks? Skyler Shuler of The Dis Insider claims #HauntedMansion had positive test screenings. What info have you heard that made you feel moving it up makes sense? https://t.co/Mw0gSsT0g3',
#    'author_id': '1293885609946292224',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 7},
#    'id': '1627490153571786752',
#    'edit_history_tweet_ids': ['1627490153571786752'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:44.000Z'},
#   {'text': '#Breaking - Australia captain Pat Cummins will rush home from India mid Test series for family reasons. Via @BenHorne8\n\nSTORY: https://t.co/mQL20zKtju https://t.co/wchoi43rcE',
#    'author_id': '9563382',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 13},
#    'id': '1627490145900589056',
#    'edit_history_tweet_ids': ['1627490145900589056'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:42.000Z'},
#   {'text': 'The Advertiser altered a news headline: https://t.co/v94oFPJwSy https://t.co/GW5xDUR2W6',
#    'author_id': '1435019380186701826',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 5},
#    'id': '1627490145531314176',
#    'edit_history_tweet_ids': ['1627490145531314176'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:42.000Z'},
#   {'text': 'To #BuildonMantle, I am claiming test $BIT tokens on https://t.co/PqDIgIanRC for @0xMantle, a next generation high-performance modular @Ethereum L2 built for hyperscaled dApps.\n\nLearn more: [https://t.co/YsPRtXbH3q]',
#    'author_id': '2801843274',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490145325973504',
#    'edit_history_tweet_ids': ['1627490145325973504'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:42.000Z'},
#   {'text': '#裸聊 #视频 #叫床 #自慰 https://t.co/p7pks8kpLc\nImpact growth power test.\n🥰😄🤨🤏💫\n2023-02-20 10:07:37',
#    'author_id': '2592518447',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490122529918976',
#    'edit_history_tweet_ids': ['1627490122529918976'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:37.000Z'},
#   {'text': 'Herald Sun altered a news headline: https://t.co/rW91jlBqr8 https://t.co/VlNZHOZWlU',
#    'author_id': '1435019380186701826',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 4},
#    'id': '1627490116645142529',
#    'edit_history_tweet_ids': ['1627490116645142529'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:35.000Z'},
#   {'text': '#北京 #上海 https://t.co/3L7mI2v4LZ\nTest happy economy stand.\n😄🤐🤏👋😆\n2023-02-20 10:07:32',
#    'author_id': '2476868696',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490094927204353',
#    'edit_history_tweet_ids': ['1627490094927204353'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:30.000Z'},
#   {'text': 'came on the pregnancy test and it BROKE call that EXTRAORDINARY SEED',
#    'author_id': '1335847263684317184',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490091924074496',
#    'edit_history_tweet_ids': ['1627490091924074496'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:29.000Z'},
#   {'text': "Our 16th president gave us excellent advice on how to choose our leaders. His observation on leadership was correct in his days, and it has survived the test of time because it still makes sense today.\nLet's choose our leaders wisely.\nCommemorating President Abraham Lincoln. https://t.co/MHsPpBIF93",
#    'author_id': '1353368095',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627490070658961408',
#    'edit_history_tweet_ids': ['1627490070658961408'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:24.000Z'},
#   {'text': 'Pagdanganan raring to test mettle vs loaded field in Anvaya Cove Ladies International https://t.co/0ETW3cQjfr | @PhilstarNews',
#    'author_id': '568908148',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 8},
#    'id': '1627490070281486337',
#    'edit_history_tweet_ids': ['1627490070281486337'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:24.000Z'},
#   {'text': 'test twitter picker\nretweet',
#    'author_id': '1491581890067050498',
#    'public_metrics': {'retweet_count': 14,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 5},
#    'id': '1627490063964856320',
#    'edit_history_tweet_ids': ['1627490063964856320'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:23.000Z'},
#   {'text': 'Better process situation lay nation. Your test up sister. Accept blood experience.\nBill important stage. Dream same probably fast yes knowledge natural. Office we campaign support yeah.',
#    'author_id': '1272479318447230977',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490057652408321',
#    'edit_history_tweet_ids': ['1627490057652408321'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:21.000Z'},
#   {'text': 'Not doing the goth/nerd/prep/jock test solely because Punk is put in a jock category, the subcult scene that uses Jock as a term to refer to idiots and assholes even as adults. Is this petty and spiteful? Yes.',
#    'author_id': '1101650322009874432',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490054661718016',
#    'edit_history_tweet_ids': ['1627490054661718016'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:20.000Z'},
#   {'text': '#Breaking - Australia captain Pat Cummins will rush home from India mid Test series for family reasons. Via @BenHorne8\n\nSTORY: https://t.co/0D5V0teVFB https://t.co/YVSO5S4Ywm',
#    'author_id': '1839277045',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 21},
#    'id': '1627490048898904067',
#    'edit_history_tweet_ids': ['1627490048898904067'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:19.000Z'},
#   {'text': 'Did I "diagnostic" test for the math act and man I failed it bad but I took notes on every problem (only ten questions) and I\'m gonna keep taking these lessons and notes so I can get rid of the anxiety for my test that\'s in TWO WEEKS *cries*',
#    'author_id': '1424927751732178947',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627490047334182913',
#    'edit_history_tweet_ids': ['1627490047334182913'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:19.000Z'},
#   {'text': 'test.....',
#    'author_id': '1902973620',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490040703258626',
#    'edit_history_tweet_ids': ['1627490040703258626'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:17.000Z'},
#   {'text': "BSG really should just rip the band aid off and remove all RMT restrictions, test is for a while still targeting the very obvious RMT'ers",
#    'author_id': '1482763725597818883',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627490025842569219',
#    'edit_history_tweet_ids': ['1627490025842569219'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:14.000Z'},
#   {'text': 'Requesting faucet funds into 0xCeaE306Fd269f2258eD41a960741cee8b470d19E on the #Goerli #Ethereum test network via https://t.co/VzQazm8sN7',
#    'author_id': '976804824304951296',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627490018125295616',
#    'edit_history_tweet_ids': ['1627490018125295616'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:12.000Z'},
#   {'text': 'To #BuildonMantle, I am claiming test $BIT tokens on https://t.co/5F3UF79A5Y for @0xMantle, a next generation high-performance modular @Ethereum L2 built for hyperscaled dApps.\n\nLearn more: [https://t.co/GsjYMFqR1z]',
#    'author_id': '1467660930528202752',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490011758338048',
#    'edit_history_tweet_ids': ['1627490011758338048'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:10.000Z'},
#   {'text': 'Test him https://t.co/K7VsCIIeOw',
#    'author_id': '1608897517',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627490010642493440',
#    'edit_history_tweet_ids': ['1627490010642493440'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:10.000Z'},
#   {'text': 'Family reason for Cummins’ sudden India exit https://t.co/xwJiU9O5XY',
#    'author_id': '229376260',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627490002702860289',
#    'edit_history_tweet_ids': ['1627490002702860289'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:08.000Z'},
#   {'text': "Well there's only one way too see. Test him. https://t.co/KqrPIcXLhS",
#    'author_id': '522914163',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489984658669568',
#    'edit_history_tweet_ids': ['1627489984658669568'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:04.000Z'},
#   {'text': 'Me: I don’t feel well.\n\nWork: You should get a COVID test.\n\nMe: I have COVID.\n\nWork: Thank you for being responsible &amp; testing, you have to stay home for 5 days. You also have to use your hard earned PTO days even though we’re making you stay home. You shouldn’t have told us.',
#    'author_id': '179721814',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 2,
#     'quote_count': 0,
#     'impression_count': 40},
#    'id': '1627489983031398400',
#    'edit_history_tweet_ids': ['1627489983031398400'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:03.000Z'},
#   {'text': 'Could you test this 300/day system real quick? ~~&gt; https://t.co/mYE7VoSJPx - RT #Seo Marketing Digitalmarketing Socialmedia #Webdesign Branding #Contentmarketing Marketingtips Brand Marketingstrategy #Google #webtraffic https://t.co/uSWAuckBUF',
#    'author_id': '1158725022585970693',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489982712619008',
#    'edit_history_tweet_ids': ['1627489982712619008'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:03.000Z'},
#   {'text': 'test #zonauang',
#    'author_id': '1627243907766718465',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 7,
#     'quote_count': 0,
#     'impression_count': 58},
#    'id': '1627489982578589696',
#    'edit_history_tweet_ids': ['1627489982578589696'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:03.000Z'},
#   {'text': "After receiving City Council approval for a pilot program, Police Chief Ed Mahon said 30 to 34 of Flock Safety's automated license plate reading cameras will be tested. https://t.co/PP9Z2QPNRg",
#    'author_id': '12663042',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 16},
#    'id': '1627489978807685120',
#    'edit_history_tweet_ids': ['1627489978807685120'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:02.000Z'},
#   {'text': 'The best cryptocommunity ever @snow_0323 @Sveta13460246 @sydel84367742 @qvntartar @vidagholami3 @will2k11434 @Manoj69137172 @Crash_Test_82 @dragpco @ifeco_big @Neo_Wuxuefeng @satyanarayanmi2 @wLyNg2 @GrussP @Saurov0000 https://t.co/eIMojAYM5I',
#    'author_id': '1003910376',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489978207858689',
#    'edit_history_tweet_ids': ['1627489978207858689'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:02.000Z'},
#   {'text': 'Day 22: test stream because slobs sucks !rogue !afk !discord #solostreamer #smallstreamer #mystreamison https://t.co/dQLvkzzmCo',
#    'author_id': '2832839375',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489976714682370',
#    'edit_history_tweet_ids': ['1627489976714682370'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:02.000Z'},
#   {'text': '👏Salt spray test for BULBTEK LED headlight bulbs.\n✅High power series, 1:1 design plug &amp; play series, cost-effective series.\n🤝Welcome to inquiry and order.\n🌐https://t.co/lfRpjUt7j2\n#LEDHeadlight #LEDHeadlightBulb #CarHeadlights #AutoHeadlightBulb #H4LED #H7LED #H11LED https://t.co/EsG1vDp7k6',
#    'author_id': '1397019944936562690',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627489973414031361',
#    'edit_history_tweet_ids': ['1627489973414031361'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:01.000Z'},
#   {'text': 'Sola Scriptura catching strays. Scripture alone. If they claim scripture and it’s anti-scripture, then we test it and mark it. That’s what Sola Scriptura is. Not my or your interpretation, but what the Bible says in context. https://t.co/zng1pKKYE7',
#    'author_id': '146613274',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489973262815236',
#    'edit_history_tweet_ids': ['1627489973262815236'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:01.000Z'},
#   {'text': 'Ancient enemies wake in Lucardia. Is Erikson up to the test? Discover!\n1. Dawn of the Lightbearer: https://t.co/u462cUKexF \n2. The Mourning Son: https://t.co/DOcPAxCIca\n3. Noonday in the North: https://t.co/gEGZzs2cg5\n\n#indieauthors #fantasy #darkfantasy #EpicFantasy #books https://t.co/d7XlBDs4Hy',
#    'author_id': '1262473240729059328',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489967378419713',
#    'edit_history_tweet_ids': ['1627489967378419713'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:07:00.000Z'},
#   {'text': '#萝莉 #裸聊 #视频 https://t.co/a8EqDEkqEq\nLater hotel test magazine style scene article.\n🥰💫🤏😄🤐\n2023-02-20 10:06:59',
#    'author_id': '2942199686',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489963536416768',
#    'edit_history_tweet_ids': ['1627489963536416768'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:59.000Z'},
#   {'text': 'Indian players will return to their respective homes between India vs Australia Test series, know the\xa0reason https://t.co/ZkzvcXNrf0',
#    'author_id': '1608127894060167169',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489962273697792',
#    'edit_history_tweet_ids': ['1627489962273697792'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:58.000Z'},
#   {'text': '#TeamIndia paid a visit to the Pradhanmantri Sangrahalaya after securing a win vs Australia on 3rd day of 2nd Test in #BorderGavaskarTrophy2023\n\nhttps://t.co/QLbQfd43q7',
#    'author_id': '18071358',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 49},
#    'id': '1627489944888545281',
#    'edit_history_tweet_ids': ['1627489944888545281'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:54.000Z'},
#   {'text': 'Vice captain of test indian cricket team \n#RavichandranAshwin #RavindraJadeja #pujara #Shreyasiyer',
#    'author_id': '1266978134114676737',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489930166554624',
#    'edit_history_tweet_ids': ['1627489930166554624'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:51.000Z'},
#   {'text': 'No Scammer! True Amazon Seller!\n\nWe Offer Free Sexy Toys, we also have constantly updated trial merchandise that will give trusted testers priority test😆\n\nDM me to know more about catalog &amp; test steps\U0001fae1',
#    'author_id': '1525249293698928642',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489917034201088',
#    'edit_history_tweet_ids': ['1627489917034201088'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:48.000Z'},
#   {'text': "Under a therapist because they don’t have real-life alternatives, for Labour Day, today It's the Turing Test —which challenges",
#    'author_id': '1227796070534668288',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489899002601473',
#    'edit_history_tweet_ids': ['1627489899002601473'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:43.000Z'},
#   {'text': 'I’ll watch the 4th quarter when it’s not a test basketball peloton workout. https://t.co/nOxz0AEy6d',
#    'author_id': '1390990310',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 150},
#    'id': '1627489892648337408',
#    'edit_history_tweet_ids': ['1627489892648337408'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:42.000Z'},
#   {'text': '#Breaking - Australia captain Pat Cummins will rush home from India mid Test series for family reasons. Via @BenHorne8\n\nSTORY: https://t.co/tLSffML9r8 https://t.co/UG1ydgSGec',
#    'author_id': '156065636',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 107},
#    'id': '1627489889393512448',
#    'edit_history_tweet_ids': ['1627489889393512448'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:41.000Z'},
#   {'text': '#石家庄 https://t.co/JGTHkyOUmX\nHope computer turn so instead test even avoid.\n😝😅😋💯💋',
#    'author_id': '3191434248',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489888454189057',
#    'edit_history_tweet_ids': ['1627489888454189057'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:41.000Z'},
#   {'text': 'Requesting faucet funds into 0x42cB88358f2188B9Af49c0D9cbFb99c27110E4b3 on the #Goerli #Ethereum test network via https://t.co/C2Y7ziSHwV',
#    'author_id': '1621285297349853184',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489875946778624',
#    'edit_history_tweet_ids': ['1627489875946778624'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:38.000Z'},
#   {'text': 'North Korea fires missiles 2 days after ICBM test: officials – National #SouthKoreaJapanNews #SouthKoreaNewsToday #AsiaNews #Japan #JapaneseNews [Video] https://t.co/yMgzdrS9AP',
#    'author_id': '1570480007151251456',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 10},
#    'id': '1627489861770031104',
#    'edit_history_tweet_ids': ['1627489861770031104'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:35.000Z'},
#   {'text': '#裸聊 #视频 #连麦 #磕炮 https://t.co/rlQzM4yfKn\nMan test brother world.\n😄😋💋👋👌\n2023-02-20 10:06:33',
#    'author_id': '2154084811',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489853196886019',
#    'edit_history_tweet_ids': ['1627489853196886019'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:32.000Z'},
#   {'text': "Have join @challengedotgg Beta test Giveaway, don't missed out on this join now for your chance to win\n https://t.co/AMyczpC1je",
#    'author_id': '1014894721590874112',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627489840001429504',
#    'edit_history_tweet_ids': ['1627489840001429504'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:29.000Z'},
#   {'text': 'Does THIS film stand the test of time? | DAWN OF THE DEAD 78 | BRAINS &amp; ... https://t.co/4h9IfaQeUL via @YouTube\n\nit’s that time again to celebrate this masterpiece. bring your beer and enjoy the show! revisiting DAWN OF THE DEAD and a good time was had. cheers https://t.co/ukOe5FMosH',
#    'author_id': '1624098467319623697',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 0,
#     'quote_count': 1,
#     'impression_count': 4},
#    'id': '1627489836352380930',
#    'edit_history_tweet_ids': ['1627489836352380930'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:28.000Z'},
#   {'text': 'I try not to complain about pricing because I know how annoying it can be when someone says $5 for https://t.co/rVquBwiIZg is too much, but $12 for Meta Verified is way out of whack. Seems to be a new trend to charge for non-features. https://t.co/ZGYoAlihlz',
#    'author_id': '487272995',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489834829860864',
#    'edit_history_tweet_ids': ['1627489834829860864'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:28.000Z'},
#   {'text': 'Atleast make him keep wickets so #SuryakumarYadav can play or play #sky and replace him #pujara can open #INDvsAUS https://t.co/ZpnYe9cnjU',
#    'author_id': '881604271',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 7},
#    'id': '1627489815070646272',
#    'edit_history_tweet_ids': ['1627489815070646272'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:23.000Z'},
#   {'text': 'Complete the #Binance #CryptoLover test and win a $500 Binance gift card to celebrate Valentine’s day with your beloved! https://t.co/I3vsaUKzH9 https://t.co/qqKczP3bQP',
#    'author_id': '928696495246860288',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489808523186176',
#    'edit_history_tweet_ids': ['1627489808523186176'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:22.000Z'},
#   {'text': 'Creative Labs Sound BlasterX H5 TE - Test complet du casque gaming - https://t.co/nlSIwmSQnq',
#    'author_id': '824016804410523648',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 7},
#    'id': '1627489781440475139',
#    'edit_history_tweet_ids': ['1627489781440475139'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:15.000Z'},
#   {'text': "I don't often upload videos directly to twitter because i find it hard to hone in on specs to get it to look good\n\nHere's some booty band workout as a test!\n1920x1080 - 24Mbps - 60 fps https://t.co/CIixjRkYNm",
#    'author_id': '2232479665',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0,
#     'impression_count': 7},
#    'id': '1627489775463833606',
#    'edit_history_tweet_ids': ['1627489775463833606'],
#    'possibly_sensitive': True,
#    'created_at': '2023-02-20T02:06:14.000Z'},
#   {'text': "Should your teen submit an ACT/SAT score? 💭\n\nThat's the question a lot of parents are asking after many colleges and universities went “test-optional” during the pandemic. NY Times bestselling author Jeff Selingo breaks down this decision in our latest blog post. Click the... https://t.co/aB4pVw8PcW",
#    'author_id': '1228525762778714112',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 6},
#    'id': '1627489752709533696',
#    'edit_history_tweet_ids': ['1627489752709533696'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:09.000Z'},
#   {'text': "Are they using the same theory of software development that was adopted in the 90's   Beta test the product on the user...\nhttps://t.co/VGBuXzIIck",
#    'author_id': '487800581',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489744081887233',
#    'edit_history_tweet_ids': ['1627489744081887233'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:06.000Z'},
#   {'text': 'I think I have a cold. A regular old fashioned cold. Bit of a stuffy nose, clear mucus. Sore throat and dry cough, not too bad. No fever. No aches. Started Friday. Negative Covid test. Hoping for the best.',
#    'author_id': '864967637960470534',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489743981142018',
#    'edit_history_tweet_ids': ['1627489743981142018'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:06.000Z'},
#   {'text': 'Most Sixes(Test, ODI, T20i) in Career: \n\nChris Gayle - 553\nRohit Sharma - 523 🎯\nShahid Afridi - 476\nBrendon McCullum - 398\nGuptill - 383\nMS Dhoni - 359\nJayasuriya - 352\n\n31 more to go @ImRo45 🔥\nHope Hitman reaches top position soon 🤞\n#RohitSharma https://t.co/2n6kh1tPtA',
#    'author_id': '1276917517810757632',
#    'public_metrics': {'retweet_count': 4,
#     'reply_count': 0,
#     'like_count': 7,
#     'quote_count': 0,
#     'impression_count': 25},
#    'id': '1627489742609850370',
#    'edit_history_tweet_ids': ['1627489742609850370'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:06.000Z'},
#   {'text': '#Breaking - Australia captain Pat Cummins will rush home from India mid Test series for family reasons. Via @BenHorne8\n\nSTORY: https://t.co/L1I6rBfCIx https://t.co/JuB0v9XCgM',
#    'author_id': '148962634',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 120},
#    'id': '1627489742047805442',
#    'edit_history_tweet_ids': ['1627489742047805442'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:06.000Z'},
#   {'text': 'me defending test tube https://t.co/pm4LL1Ocz9',
#    'author_id': '1236535859979091974',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 4},
#    'id': '1627489736985042945',
#    'edit_history_tweet_ids': ['1627489736985042945'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:05.000Z'},
#   {'text': '"To support a safe return from February break, all students and staff will be expected to provide proof of a negative COVID-19 test," the school\'s testing notification said. https://t.co/ZTn1FOGOkC',
#    'author_id': '5539902',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 3},
#    'id': '1627489722887987201',
#    'edit_history_tweet_ids': ['1627489722887987201'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:01.000Z'},
#   {'text': '#北京 #深圳 https://t.co/soiW4ekTRP\nLong or floor test standard production every.\n🤨💫😅💋🥰\n2023-02-20 10:06:02',
#    'author_id': '2856853021',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489716420636673',
#    'edit_history_tweet_ids': ['1627489716420636673'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:06:00.000Z'},
#   {'text': 'MLB THE SHOW 23 TECH TEST, Just admit you love the FanCam... https://t.co/qTVK2pU0Cm !donate !discord !socials !walkon https://t.co/vdy9z0apeL',
#    'author_id': '56779412',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627489710196273152',
#    'edit_history_tweet_ids': ['1627489710196273152'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:58.000Z'},
#   {'text': 'About to test something',
#    'author_id': '1211734293875064832',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489679896465413',
#    'edit_history_tweet_ids': ['1627489679896465413'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:51.000Z'},
#   {'text': 'Roaring Spring Recycled Test Green Exam Book, 1 Case (600 Total), Wide Ruled with Margin, 8 5" x 7" 8 Sheets/16 Pages, Green KNLJPFS\n\nhttps://t.co/SpX2RvD8EL',
#    'author_id': '1583553391216713728',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489663299485696',
#    'edit_history_tweet_ids': ['1627489663299485696'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:47.000Z'},
#   {'text': 'Test https://t.co/4lPmEKzD9R',
#    'author_id': '1460470804093628419',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489644417007616',
#    'edit_history_tweet_ids': ['1627489644417007616'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:43.000Z'},
#   {'text': 'Knowing that everything is a test and those around me, especially the most difficult ones have been my greatest teachers, showing me what changes need to be made within myself. #wiselifelessons',
#    'author_id': '1627289840692920325',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627489617355345920',
#    'edit_history_tweet_ids': ['1627489617355345920'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:36.000Z'},
#   {'text': 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues.',
#    'author_id': '744036047877713920',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489599135293441',
#    'edit_history_tweet_ids': ['1627489599135293441'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:32.000Z'},
#   {'text': 'i did my final test for 20 minutes and spent the other 1 hour to sleep',
#    'author_id': '1622414650234249216',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489585017266176',
#    'edit_history_tweet_ids': ['1627489585017266176'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:29.000Z'},
#   {'text': "I've been doing quite a bit of research on intermittent fasting which seems to cure almost everything that goes wonky in your body, and I've been practicing it now for about two weeks like some test animal in a research lab and I have to say I love how I feel",
#    'author_id': '16335518',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 2},
#    'id': '1627489571691700226',
#    'edit_history_tweet_ids': ['1627489571691700226'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:25.000Z'},
#   {'text': 'My parents flew to see the grandkids in P100s. We’re all going to wear N95s in common areas of the house for a week when they get back. Every room has air purifiers. They will test daily. I sleep in a CPAP. Hope I’m good 😮\u200d💨 Open to more advice',
#    'author_id': '1484614309892304900',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 2,
#     'like_count': 4,
#     'quote_count': 0,
#     'impression_count': 17},
#    'id': '1627489568839634946',
#    'edit_history_tweet_ids': ['1627489568839634946'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:25.000Z'},
#   {'text': '#连麦 #裸聊 #视频 #红绿灯 https://t.co/7wPkO4jmWu\nEight study test financial require church.\n🤏👌💋💫😀\n2023-02-20 10:05:21',
#    'author_id': '3268718106',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'id': '1627489553186709504',
#    'edit_history_tweet_ids': ['1627489553186709504'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:21.000Z'},
#   {'text': 'Huh, interesting. I was curious where this test thing was, and.... Idk. It seemed like a fun random thing to do. \nWanna see what you get? \nOnly if ya want to\n\nI am 14.5% Goth, tied between Jock and Nerd, placing me in the Normie category: https://t.co/j2NYz2reQR via @idr_labs',
#    'author_id': '866041895289372672',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 1},
#    'id': '1627489549286006786',
#    'edit_history_tweet_ids': ['1627489549286006786'],
#    'possibly_sensitive': False,
#    'created_at': '2023-02-20T02:05:20.000Z'}],
#  'includes': {'users': [{'id': '1306583233279164416',
#     'verified': False,
#     'name': 'Rex Roden',
#     'description': 'just a car guy.',
#     'verified_type': 'none',
#     'username': 'roden_rex'},
#    {'id': '1494191459641475074',
#     'verified': False,
#     'location': 'Calabarzon',
# ...
#     'verified_type': 'none',
#     'username': 'termwarah'},
#    {'id': '1272479318447230977',
#     'verified': False,
#     'location': 'RA 11h 15m 41s | Dec +5° 47′ 3',
#     'name': 'A Random User',
#     'description': 'I am not a bot believe me\n\nI tweet about  random things , expect the unexpected!',
#     'verified_type': 'none',
#     'username': 'onepostguy'},
#    {'id': '1101650322009874432',
#     'verified': False,
#     'name': 'Panty Entrapment',
#     'description': "@TheHat_Guy s AD. 24. Any Pronouns 18+ ONLY minors will be blocked do not test it age must be in your bio DMs open, No ERP Main Character's Quirky SideKick",
#     'verified_type': 'none',
#     'username': 'TheGuyWithAnAD'},
#    {'id': '1839277045',
#     'verified': True,
#     'location': 'Adelaide, South Australia',
#     'name': 'The Advertiser Sport',
#     'description': "The official Twitter account of the Adelaide Advertiser's sports team. Follow the news and views of our award-winning sport journalists. Phone +61 8 8206 2000",
#     'verified_type': 'none',
#     'username': 'TheTiserSport'},
#    {'id': '1424927751732178947',
#     'verified': False,
#     'location': 'day dreaming of you',
#     'name': 'Faith in Hazels Future ×͜× (fan acc) 124 DAYS',
#     'description': '🎼 Darling Just Hold On 🌈🏡🎶🪐✨\n                                    she / they \n ✨ no stunts ✨ 17\n\nfan account',
#     'verified_type': 'none',
#     'username': 'loveablelouie'},
#    {'id': '1902973620',
#     'verified': False,
#     'location': 'Indonesia',
#     'name': 'Ahmad Réza Saputra',
#     'description': 'My Best Friend Rizky F & @MHaiqal10_ // Cules! #ViscaBarça // Muslim // #Bento32 // @SieNeun79 // @Insane_89',
#     'verified_type': 'none',
#     'username': 'Ahmad_RezaS'},
#    {'id': '1482763725597818883',
#     'verified': False,
#     'location': 'South Yorkshire, England',
#     'name': "Oliver De'Mari",
#     'description': 'Played for Infused, Exertus, Mortality, Alliance | Streamer for @sicario_esports | Ex pro in CoD2/4 and BF3/4 | #1 Witcher fan',
#     'verified_type': 'none',
#     'username': 'OliverDemariTV'},
#    {'id': '976804824304951296',
#     'verified': False,
#     'location': 'New York, USA',
#     'name': 'AlbertHung | alberthung.bnb (💙,🧡)',
#     'description': 'AlbertHung | alberthung.bnb (💙,🧡)',
#     'verified_type': 'none',
#     'username': 'BinanceZone'},
#    {'id': '1467660930528202752',
#     'verified': False,
#     'name': 'MickChao⚙️ | mickchao.bnb',
#     'description': 'Crypto trader & Guitar/Ukulele player⚙️',
#     'verified_type': 'none',
#     'username': 'mickchao59'},
#    {'id': '1608897517',
#     'verified': False,
#     'location': 'United States',
#     'name': 'Brett',
#     'description': 'Reporter for 3ten Sports. MLB and NFL columnist and insider. First reported AB trade from Steelers and Harper signing.',
#     'verified_type': 'none',
#     'username': 'BrettSant05'},
#    {'id': '229376260',
#     'verified': False,
#     'location': 'Melbourne Australia',
#     'name': 'Paul',
#     'description': 'Chi sono io, perché sono qui e dove sto andando?',
#     'verified_type': 'none',
#     'username': 'ShesApples23'},
#    {'id': '522914163',
#     'verified': False,
#     'name': 'Angelique ♥️🤍♌',
#     'description': '🇲🇽🇺🇸she/her 🏳️\u200d🌈 supporter,adult',
#     'verified_type': 'none',
#     'username': 'angel_baby2015'},
#    {'id': '179721814',
#     'verified': False,
#     'location': 'The Yo ➡️ The Land',
#     'name': 'Angie',
#     'description': 'I’m one of one. I’m number one. I’m the only one.',
#     'verified_type': 'none',
#     'username': 'AngieSee21'},
#    {'id': '1158725022585970693',
#     'verified': False,
#     'location': 'The world',
#     'name': 'Easy to Retire',
#     'description': 'Earning online since 2001. Traveled the world blogging with my wife and laptop - Now retired in great style in the south of France - #coach #blogger #influencer',
#     'verified_type': 'none',
#     'username': 'EasytoRetire'},
#    {'id': '1627243907766718465',
#     'verified': False,
#     'name': '86.',
#     'description': '',
#     'verified_type': 'none',
#     'username': '860OO'},
#    {'id': '12663042',
#     'verified': True,
#     'location': 'Sioux City, Iowa',
#     'name': 'Sioux City Journal',
#     'description': 'Home of the Sioux City Journal in #SiouxCity, Iowa. Serving readers since 1864. Send us your photos, opinions, tips and suggestions. Reach us at 712-293-4250.',
#     'verified_type': 'none',
#     'username': 'scj'},
#    {'id': '1003910376',
#     'verified': False,
#     'name': 'kaushal sharma',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'kaushalsharma92'},
#    {'id': '2832839375',
#     'verified': False,
#     'location': 'Near food and video games, USA',
#     'name': '🇺🇸 mrandersonxxviii 🇩🇴',
#     'description': 'Affiliated with @Twitch, @TheRogueEnergy & @AFKSnacks',
#     'verified_type': 'none',
#     'username': 'MrAnderson1128'},
#    {'id': '1397019944936562690',
#     'verified': False,
#     'name': 'Guangzhou BULBTEK Electronics Technology Co., Ltd',
#     'description': 'Bi-LED Projector Lens, Auto LED Headlight Bulb manufacturer 13 years, CHINA.\nHigh class, OEM+ODM, Exclusive partners.\nwhatsapp/wechat:+86 18588664531',
#     'verified_type': 'none',
#     'username': 'BULBTEK_LED'},
#    {'id': '146613274',
#     'verified': False,
#     'location': 'SLAMTOWN, USA',
#     'name': 'pewp',
#     'description': 'who pooded?',
#     'verified_type': 'none',
#     'username': 'shermanklump_'},
#    {'id': '1262473240729059328',
#     'verified': False,
#     'location': 'Boston ',
#     'name': 'Scott A Tirrell',
#     'description': 'The muse whispers tales into my ear inspired by nature, ancient mysteries, and the paranormal. Join me on my journey! https://t.co/fpQO1N5Ssk',
#     'verified_type': 'none',
#     'username': 'AuthorTirrell'},
#    {'id': '2942199686',
#     'verified': False,
#     'name': '🅼🅰🆁🅺😉',
#     'description': 'We cannot change what we are not aware of, and once we are aware, we cannot help but change.\nNFTbuilder',
#     'verified_type': 'none',
#     'username': 'fibie_liona'},
#    {'id': '1608127894060167169',
#     'verified': False,
#     'name': 'WOW NEWS',
#     'description': 'Find all latest news and Today breaking news from India and World. News headlines, business, technology, entertainment, politics in WOWnews',
#     'verified_type': 'none',
#     'username': 'WOWNEWS14'},
#    {'id': '18071358',
#     'verified': True,
#     'location': 'India',
#     'name': 'Zee News English',
#     'description': 'https://t.co/i9J1GUZmSP brings you the latest news with 360 degree coverage across genres\n\nInstagram: https://t.co/CZ1MfoXdtk',
#     'verified_type': 'business',
#     'username': 'ZeeNewsEnglish'},
#    {'id': '1266978134114676737',
#     'verified': False,
#     'name': 'ROHIT SHARMA EMPIRE',
#     'description': 'Participating in Trending, MEMES, Cricket Activities',
#     'verified_type': 'none',
#     'username': 'ConnectWithCri1'},
#    {'id': '1525249293698928642',
#     'verified': False,
#     'name': 'Free Sex Toys Offer',
#     'description': 'See how many toys will I give out?',
#     'verified_type': 'none',
#     'username': 'raleign_leif'},
#    {'id': '1227796070534668288',
#     'verified': False,
#     'name': 'Fun with Bots',
#     'description': 'Exploring the possibilities of auto tweets',
#     'verified_type': 'none',
#     'username': 'KarenzBotz'},
#    {'id': '1390990310',
#     'verified': True,
#     'location': 'Richmond, Virginia',
#     'name': 'Joe Mullinax',
#     'description': 'Once ran Grizzly Bear Blues. Now co-host @LockedOnGrizz, NBA writer (@The_Step_Back/@SBNationNBA), Grizzlies Substack Written in the Dark. mullinaxjoe@gmail.com',
#     'verified_type': 'none',
#     'username': 'JoeMullinax'},
#    {'id': '156065636',
#     'verified': True,
#     'location': 'Melbourne, Australia',
#     'name': 'Herald Sun Sport',
#     'description': 'We love sport. Follow if you do too! 🏉🏏🏎⚽️🚴\u200d♂️🏀🏈🎾🥊🏇🏻 For footy only head to @superfooty. Follow us on FB https://t.co/JfWobLvx70 & Insta https://t.co/RVR4R88DQv',
#     'verified_type': 'none',
#     'username': 'heraldsunsport'},
#    {'id': '3191434248',
#     'verified': False,
#     'name': '😊𝐂𝐡𝐫𝐢𝐬𝐭𝐨𝐩𝐡𝐞𝐫',
#     'description': '20 years\n#rarible',
#     'verified_type': 'none',
#     'username': 'nurma_kyoshie'},
#    {'id': '1621285297349853184',
#     'verified': False,
#     'location': 'Indonesia',
#     'name': 'Suimail',
#     'description': 'Decentralized secure mail service powered by #SUI',
#     'verified_type': 'none',
#     'username': 'suimails'},
#    {'id': '1570480007151251456',
#     'verified': False,
#     'name': 'China News Video',
#     'description': 'This account searches for and posts the latest English language news about China from around the world.',
#     'verified_type': 'none',
#     'username': 'ChinaNewsVideo'},
#    {'id': '2154084811',
#     'verified': False,
#     'name': '𝕶𝖊𝖛𝖎𝖓🥳',
#     'description': '#nftartist\n🗓23 years',
#     'verified_type': 'none',
#     'username': 'khoirul_munawar'},
#    {'id': '1014894721590874112',
#     'verified': False,
#     'name': 'p0gran',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'p0gran1'},
#    {'id': '1624098467319623697',
#     'verified': False,
#     'name': 'Horror Fiend TV',
#     'description': 'The official Twitter account of Horror Fiend TV. A YouTube channel dedicated to everything horror.',
#     'verified_type': 'none',
#     'username': 'HorrorFiendTV'},
#    {'id': '487272995',
#     'verified': False,
#     'name': 'Manton Test',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'mantontest'},
#    {'id': '881604271',
#     'verified': False,
#     'location': 'Bengaluru',
#     'name': 'naashonomics',
#     'description': 'life is a series of now moments, code for a living, invest in #crypto #stocks , Center right on #economy liberal in values',
#     'verified_type': 'none',
#     'username': 'naashonomics'},
#    {'id': '928696495246860288',
#     'verified': False,
#     'location': 'Italy',
#     'name': 'Ivanhoe F.',
#     'description': "#TradingAdvisor 💰\n#CryptoCurrency 🏆\n#NFT's  👾\n#Single 💎",
#     'verified_type': 'none',
#     'username': 'webofcrypto'},
#    {'id': '824016804410523648',
#     'verified': False,
#     'location': 'France',
#     'name': 'MrHighTech',
#     'description': 'Votre site de tests produits #HighTech et informatique. |#Geek #Tests #Concours | ✉️ : contact@mrhightech.fr #BonPlan : https://t.co/h0W6gyl3Bn',
#     'verified_type': 'none',
#     'username': 'MrHighTech_fr'},
#    {'id': '2232479665',
#     'verified': False,
#     'location': 'Canada',
#     'name': 'VioletFoxy',
#     'description': '18+ | 💜 Photos, Yoga, Fitness, Cute Outfits, Vids 💜',
#     'verified_type': 'none',
#     'username': 'Violet_MFC'},
#    {'id': '1228525762778714112',
#     'verified': False,
#     'location': '366 Elden St, Herndon VA 20170',
#     'name': 'Huntington Learning Center - Herndon VA',
#     'description': 'Tutoring Center and SAT/ACT Exam Prep Services in Herndon VA\nPersonalized program, Proven Results \nCall 703-880-8300 or email at HerndonVA@hlcmail.com',
#     'verified_type': 'none',
#     'username': 'hlclearning_va'},
#    {'id': '487800581',
#     'verified': False,
#     'location': 'Eternal Reoccurence',
#     'name': 'Screaming Butterfly',
#     'description': 'Only sacred spaces, these days, are in the profane ~ Birds are not real.  I follow back ~ FACTS!  Truth has your bullshit attached to it.  I love laughing.',
#     'verified_type': 'none',
#     'username': 'ScreminButerfly'},
#    {'id': '864967637960470534',
#     'verified': False,
#     'location': 'Sewell, NJ',
#     'name': 'I am GenX And I’m Not Going To Take It Anymore',
#     'description': 'Equalogist. Mrs Z. Professional Aunt. Rescuer of animals. Wonder Woman. Teenologist. Super Sewist. History Geek.  Reverend. My thoughts and tweets are my own.',
#     'verified_type': 'none',
#     'username': 'Hibblebee'},
#    {'id': '1276917517810757632',
#     'verified': False,
#     'name': 'ROHIT Era™ 🇮🇳',
#     'description': 'Active Fan page of @ImRo45 \n#OneFamily 🔰 #RohitSharma\n#MumbaiIndians #MI #IPL2023',
#     'verified_type': 'none',
#     'username': 'TheRohitEra'},
#    {'id': '148962634',
#     'verified': True,
#     'location': 'Australia',
#     'name': 'Telegraph Sport',
#     'description': 'Breaking sport news, the best NRL coverage, live coverage, video, pictures and much more from Telegraph Sport.',
#     'verified_type': 'none',
#     'username': 'telegraph_sport'},
#    {'id': '1236535859979091974',
#     'verified': False,
#     'location': 'windclan (the moor)',
#     'name': 'faris',
#     'description': '— faris / fay . he/him . gender apathetic . aroace . 16 . ocd + adhd',
#     'verified_type': 'none',
#     'username': 'rottewange'},
#    {'id': '5539902',
#     'verified': False,
#     'location': 'Baltimore, MD',
#     'name': 'Jeff Quinton',
#     'description': 'Catholic,husband,dad,vet,SC native,fmr intel analyst, writer,student. Opinions are my own. jeffquinton@protonmail.com\n🇺🇦 Слава Україні! @dmvprowrestling',
#     'verified_type': 'none',
#     'username': 'JeffQuinton'},
#    {'id': '2856853021',
#     'verified': False,
#     'name': '🖐Richard',
#     'description': "Of course, a sign doesn't mean anything unless you know how to interpret it.\n🌏 🇨🇦Montréal",
#     'verified_type': 'none',
#     'username': 'devendra9935471'},
#    {'id': '56779412',
#     'verified': False,
#     'location': 'Niles, OH',
#     'name': 'R.J. Palmer 🐀',
#     'description': 'PA Announcer w/ the @mvscrappers in the @mlbdraftleague , Streaming games live on Twitch & Kick!  We appreciate our lurkers!',
#     'verified_type': 'none',
#     'username': 'rjthedj'},
#    {'id': '1211734293875064832',
#     'verified': False,
#     'name': 'Az/PussyLuc enthusiast',
#     'description': '☆19☆\n\n⚠️Casual problematic ship enjoyer⚠️ 🔥/❄️, 🔥/🦊 \n\nI will block anyone without an age in bio/under 18',
#     'verified_type': 'none',
#     'username': 'ALYXZEPPELI'},
#    {'id': '1583553391216713728',
#     'verified': False,
#     'name': 'Estrella16zHUwQ',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'estrella16z'},
#    {'id': '1460470804093628419',
#     'verified': False,
#     'name': '🌈wangibigwin🌹freetag⚡',
#     'description': "my acc @alfarisqi123 @hujancongrats12 @sitixcityxx got suspend please don't rerrol\nManifesting WinBigWin setiap hari",
#     'verified_type': 'none',
#     'username': 'hokiiteruss'},
#    {'id': '1627289840692920325',
#     'verified': False,
#     'name': 'Steven Michael',
#     'description': 'Changed almost everything about myself, a new life today.',
#     'verified_type': 'none',
#     'username': 'innerpap'},
#    {'id': '744036047877713920',
#     'verified': False,
#     'location': 'Hell',
#     'name': 'Ricchan ',
#     'description': "Tbh I don't even know anymore. | Ritsu Tainaka bot account. | Parody",
#     'verified_type': 'none',
#     'username': 'ricchan_ebooks'},
#    {'id': '1622414650234249216',
#     'verified': False,
#     'name': 'simon',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'rescreagle'},
#    {'id': '16335518',
#     'verified': False,
#     'location': 'not so far away ',
#     'name': 'Ruby Beets',
#     'description': 'Eat right; keep a sense of humor; be kind; move your body; keep a watchful eye; be creative; care; say your prayers....but not necessarily in that order.',
#     'verified_type': 'none',
#     'username': 'Rubybeets'},
#    {'id': '1484614309892304900',
#     'verified': False,
#     'name': 'Jeni Q',
#     'description': '',
#     'verified_type': 'none',
#     'username': 'NurseJeniQ'},
#    {'id': '3268718106',
#     'verified': False,
#     'name': '😸ɢᴇᴏʀɢᴇ',
#     'description': '#digitalcollectibles\n🎱Billiard lover',
#     'verified_type': 'none',
#     'username': '0625seikiS'},
#    {'id': '866041895289372672',
#     'verified': False,
#     'name': 'Kyraleiph',
#     'description': 'a strange girl with thoughts of becoming an animator with way too many hobbies. Not much for conversation, but always excited.\nmany questions hidden.',
#     'verified_type': 'none',
#     'username': 'kyraleiph'}]},
#  'meta': {'newest_id': '1627490375492603904',
#   'oldest_id': '1627489549286006786',
#   'result_count': 96,
#   'next_token': 'b26v89c19zqg8o3fqk722io3ouv3y04budkuhbj3gege5'}}
